# %%
# Gain Insights into Data via Different Chart Types

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = (12,5)
plt.rcParams['figure.dpi'] = 150

# %%
# Auto MPGData Set
# * from https://archive.ics.uci.edu/ml/datasets/auto+mpg

# Import dataset (excel file)
data = pd.read_csv('auto-mpg.csv', index_col='name')

# %%
data.head()
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0        130    3504
# buick skylark 320          15.0          8         350.0        165    3693
# plymouth satellite         18.0          8         318.0        150    3436
# amc rebel sst              16.0          8         304.0        150    3433
# ford torino                17.0          8         302.0        140    3449
#
#                            acceleration  model_year  origin
# name
# chevrolet chevelle malibu          12.0          70       1
# buick skylark 320                  11.5          70       1
# plymouth satellite                 11.0          70       1
# amc rebel sst                      12.0          70       1
# ford torino                        10.5          70       1

# %%
plt.hist(data.mpg)
plt.title('MPG')
plt.show()

# %%
data.origin.unique()
# Out:
# array([1, 3, 2])

# %%
data1 = data.loc[data['origin'] == 1]
data1.head()
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0        130    3504
# buick skylark 320          15.0          8         350.0        165    3693
# plymouth satellite         18.0          8         318.0        150    3436
# amc rebel sst              16.0          8         304.0        150    3433
# ford torino                17.0          8         302.0        140    3449
#
#                            acceleration  model_year  origin
# name
# chevrolet chevelle malibu          12.0          70       1
# buick skylark 320                  11.5          70       1
# plymouth satellite                 11.0          70       1
# amc rebel sst                      12.0          70       1
# ford torino                        10.5          70       1

# %%
data2 = data.loc[data['origin'] == 2]
data3 = data.loc[data['origin'] == 3]

# %%
# Define howmany subplot in each row and column
fig, axes = plt.subplots(nrows=3, ncols=1)

# Assign data to each subplot

ax0, ax1, ax2 = axes.flat

ax0.hist(data1.mpg)
ax0.set_title('Region 1')

ax1.hist(data2.mpg)
ax1.set_title('Region 2')

ax2.hist(data3.mpg)
ax2.set_title('Region 3')

plt.tight_layout()

plt.show();

# %%
data.cylinders.unique()
# Out:
# array([8, 4, 6, 3, 5])

# %%
import seaborn as sns
g = sns.FacetGrid(data, col='cylinders')
g.map(plt.hist, 'mpg');

# %%
g = sns.FacetGrid(data, col='origin')
g.map(plt.hist, 'mpg');

# %%
g = sns.FacetGrid(data, row='origin')
g.map(plt.hist, 'mpg');
